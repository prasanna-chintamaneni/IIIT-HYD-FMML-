# %% [markdown]
# <a href="https://colab.research.google.com/github/prasanna-chintamaneni/IIIT-HYD-FMML-/blob/main/01_Elementary_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Command line operations, cpuinfo, meminfo, version of python, listing of files, working directory, fetching remote online objects

# %% [markdown]
# Operators in Python
#
# ![types-of-python-operators-768x299.webp](data:image/webp;base64,...)

# %% [markdown]
# Assignment Operators
# ![assignment-operators-in-java-768x802.webp](data:image/webp;base64,...)

# %%
a, b = 3, 4

# %% [markdown]
# #### Basic Arithmetic Operations
# " addition + ,  subtraction  -  , multiplication  *  , division /  ,  exponent ** , modulus  %  , floor division  // "
#
# ![arithmetic-operators-in-java-768x476.webp](data:image/webp;base64,...)

# %% [markdown]
# Operators on Strings

# %% [markdown]
# Exercise: Volume of brick

# %% [markdown]
# Exercise (Advanced): Function for finding volume, given three sides

# %% [markdown]
# Comparison Operators
#
# ![comparison-operators-in-java-768x605.webp](data:image/webp;base64,...)

# %% [markdown]
# Logical Operators
#
# ![logical-operators-in-java-768x409.webp](data:image/webp;base64,...)

# %% [markdown]
# Membership Operators
#
# ![membership-operators-in-java-768x409.webp](data:image/webp;base64,...)

# %% [markdown]
# Bitwise Operators
#
# ![bitwise-operators-in-java-768x452.webp](data:image/webp;base64,...)

# %% [markdown]
# #### References

# %% [markdown]
# 1. [Python Operators](https://www.w3schools.com/python/python_operators.asp) and [Python Exercises](https://www.w3schools.com/python/exercise.asp)
# 2. [Official Python Documentation](https://docs.python.org/3/tutorial/introduction.html)
